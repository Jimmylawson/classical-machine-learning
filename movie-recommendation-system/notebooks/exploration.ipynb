# %% [raw]
# from data.raw import ml-100k

# %%
from pathlib import Path
import sys
from shutil import move

# 1. Find the directory where the kernel is running.
PROJECT_ROOT = Path.cwd()

# 2. If that directory is notebooks/, move up to the project root.
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent

# 3. Add the project root to Python's import search path.
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# 4. Python can now find src/data.py.
from src.data import load_movies, load_ratings

# %%
ratings = load_ratings()
movies = load_movies()
movie_details = movies[["movie_id", "title"]].copy()
movie_details.head()
rating_details = ratings[["user_id","movie_id","rating"]].copy()
rating_details.head()
# Out:
#    user_id  movie_id  rating
# 0      196       242       3
# 1      186       302       3
# 2       22       377       1
# 3      244        51       2
# 4      166       346       1

# %%
print(rating_details.shape)
print(movie_details.shape)
print(rating_details["user_id"].nunique())
print(rating_details['movie_id'].nunique())
# Out:
# (100000, 3)
# (1682, 2)
# 943
# 1682
